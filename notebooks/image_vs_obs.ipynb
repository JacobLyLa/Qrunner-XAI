# %%
import os
os.chdir('../')
# Out:
# /mnt/c/Users/Jacob/Desktop/prosjektoppgave/tcav_atari/src

# %%
import matplotlib.pyplot as plt
import numpy as np

from utils import load_game_data

# %%
game_data = load_game_data()

# %%
idx = 500
obs = game_data[idx].observation
image = game_data[idx].image

# %%
obs = np.concatenate(obs.reshape(4, 84, 84), axis=1)
plt.imshow(obs, cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.savefig('../figures/observation.png')
plt.show()

# %%
plt.imshow(image)
plt.axis('off')
plt.tight_layout()
plt.savefig('../figures/image.png')
plt.show()
